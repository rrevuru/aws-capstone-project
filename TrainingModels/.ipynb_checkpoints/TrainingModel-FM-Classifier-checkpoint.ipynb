# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd
import numpy as np
import sagemaker
import boto3,io,json
from sklearn.model_selection import train_test_split
import sagemaker.amazon.common as smac
from sagemaker import get_execution_role
from sagemaker.predictor import json_deserializer
from scipy.sparse import lil_matrix
from sagemaker.amazon.amazon_estimator import get_image_uri
sage_client = boto3.Session().client('sagemaker')

# %% [markdown]
# ## Downloading dataset from S3 bucket

# %%
# !aws s3 cp s3://movies-mlready-bucket/run-1607268992801-part-r-00000.csv .
# Out:
# download: s3://movies-mlready-bucket/run-1607268992801-part-r-00000.csv to ./run-1607268992801-part-r-00000.csv

# %% [markdown]
# ## Reading the CSV file into dataframe, and converting date type to integer

# %%
df = pd.read_csv('run-1607268992801-part-r-00000.csv')

# %%
df = df.drop(df[df.userid == 'userId'].index)

# %%
df.userid = df.userid.astype(int)
df.movieid = df.movieid.astype(int)
df.rating = df.rating.astype(float)
df.movieid = df.movieid.astype(int)

# %%
df = df.drop(['timestamp'], axis=1)

# %%
train, test = train_test_split(df, test_size=0.33,random_state=42)

# %%
nb_users= train['userid'].max()
nb_movies=train['movieid'].max()
nb_features=nb_users+nb_movies
nb_ratings_train=len(train.index)
nb_ratings_test=len(test.index)
print (" # of users: ", nb_users)
print (" # of movies: ", nb_movies)
print (" Training Count: ", nb_ratings_train)
print (" Testing Count: ", nb_ratings_test)
print (" Features (# of users + # of movies): ", nb_features)
# Out:
#  # of users:  610
#  # of movies:  193609
#  Training Count:  67560
#  Testing Count:  33276
#  Features (# of users + # of movies):  194219

# %% [markdown]
# ## Helper function to create LIL Matrix with users, movies, and label vector. Only with ratings more than 4 were create labels

# %%
def loadDataset(df, lines, columns):
    # Features are one-hot encoded in a sparse matrix
    X = lil_matrix((lines, columns)).astype('float32')
    # Labels are stored in a vector
    Y = []
    line=0
    for index, row in df.iterrows():
            X[line,row['userid']-1] = 1
            X[line, nb_users+(row['movieid']-1)] = 1
            if int(row['rating']) >= 4:
                Y.append(1)
            else:
                Y.append(0)
            line=line+1

    Y=np.array(Y).astype('float32')            
    return X,Y


X_train, Y_train = loadDataset(train, nb_ratings_train, nb_features)
X_test, Y_test = loadDataset(test, nb_ratings_test, nb_features)

# %%
print(X_train.shape)
print(Y_train.shape)
assert X_train.shape == (nb_ratings_train, nb_features)
assert Y_train.shape == (nb_ratings_train, )
zero_labels = np.count_nonzero(Y_train)
print("Training labels: %d zeros, %d ones" % (zero_labels, nb_ratings_train-zero_labels))

print(X_test.shape)
print(Y_test.shape)
assert X_test.shape  == (nb_ratings_test, nb_features)
assert Y_test.shape  == (nb_ratings_test, )
zero_labels = np.count_nonzero(Y_test)
print("Test labels: %d zeros, %d ones" % (zero_labels, nb_ratings_test-zero_labels))
# Out:
# (67560, 194219)
# (67560,)
# Training labels: 66627 zeros, 933 ones
# (33276, 194219)
# (33276,)
# Test labels: 32839 zeros, 437 ones

# %% [markdown]
# ## Data repositories for input/output & model artifacts

# %%
#Change this value to your own bucket name
bucket = 'movies-mlready-bucket'
prefix = 'FM-classifier'

train_key      = 'train.protobuf'
train_prefix   = '{}/{}'.format(prefix, 'train')

test_key       = 'test.protobuf'
test_prefix    = '{}/{}'.format(prefix, 'test')


output_prefix  = 's3://{}/{}/output'.format(bucket, prefix)

# %% [markdown]
# ## Helper function to convert the training and test data into record-io

# %%
def writeDatasetToProtobuf(X, bucket, prefix, key, d_type, Y=None):
    buf = io.BytesIO()
    if d_type == "sparse":
        smac.write_spmatrix_to_sparse_tensor(buf, X, labels=Y)
    else:
        smac.write_numpy_to_dense_tensor(buf, X, labels=Y)
        
    buf.seek(0)
    obj = '{}/{}'.format(prefix, key)
    boto3.resource('s3').Bucket(bucket).Object(obj).upload_fileobj(buf)
    return 's3://{}/{}'.format(bucket,obj)
    
fm_classifier_train_data_path = writeDatasetToProtobuf(X_train, bucket, train_prefix, train_key, "sparse", Y_train)
fm_classifier_test_data_path  = writeDatasetToProtobuf(X_test, bucket, test_prefix, test_key, "sparse", Y_test)

  
print ("Training data S3 path: ",fm_train_data_path)
print ("Test data S3 path: ",fm_test_data_path)
print ("FM model output S3 path: {}".format(output_prefix))
# Out:
# Training data S3 path:  s3://movies-mlready-bucket/fm/train/train.protobuf
# Test data S3 path:  s3://movies-mlready-bucket/fm/test/test.protobuf
# FM model output S3 path: s3://movies-mlready-bucket/fm/output

# %% [markdown]
# ## Create a Factorization Machines estimator

# %%
instance_type='ml.m5.large'
role = 'arn:aws:iam::719009365707:role/role_sagemaker'
fm_classifier = sagemaker.estimator.Estimator(get_image_uri(boto3.Session().region_name, "factorization-machines"),
                                   role, 
                                   train_instance_count=1, 
                                   train_instance_type=instance_type,
                                   base_job_name='FM-classifier',
                                   output_path=output_prefix,
                                   sagemaker_session=sagemaker.Session())

fm_classifier.set_hyperparameters(feature_dim=nb_features,
                      predictor_type='binary_classifier',
                      mini_batch_size=1000,
                      num_factors=64,
                      epochs=200)

# %% [markdown]
# ## HPO Tuner and objective metric name

# %%
hyperparameter_ranges = {'bias_init_sigma': ContinuousParameter(1e-8, 32),
                         'bias_lr': ContinuousParameter(1e-8,32),
                         'bias_wd': ContinuousParameter(1e-8,32),
                         'linear_init_sigma': ContinuousParameter(1e-8, 32),
                         'linear_lr': ContinuousParameter(1e-8,32),
                         'linear_wd': ContinuousParameter(1e-8,32),
                         'factors_init_sigma': ContinuousParameter(1e-8, 32),
                         'factors_lr': ContinuousParameter(1e-8,32),
                         'factors_wd': ContinuousParameter(1e-8,32)}

# %% [markdown]
# ## Objective Metric Name = Binary classification accuracy

# %%
objective_metric_name = 'test:binary_classification_accuracy'

# %% [markdown]
# ## HPO Tuner Initialization and fitting the tuner

# %%
tuner_classifier = HyperparameterTuner(fm,
                            objective_metric_name,
                            hyperparameter_ranges,
                            base_tuning_job_name='FM-classifier',
                            max_jobs=5,
                            max_parallel_jobs=3,
                            early_stopping_type='Auto')

# %%
tuner_classifier.fit({'train': fm_classifier_train_data_path, 'test': fm_classifier_test_data_path})

# %% [markdown]
# ## Creating an endpoint for Predictions

# %%
fm_classifier_pred = tuner_classifier.deploy(instance_type='ml.m5.large', 
                            initial_instance_count=1,)
# Out:
# 2020-12-22 20:55:25 Starting - Preparing the instances for training
# 2020-12-22 20:55:25 Downloading - Downloading input data
# 2020-12-22 20:55:25 Training - Training image download completed. Training in progress.
# 2020-12-22 20:55:25 Uploading - Uploading generated training model
# 2020-12-22 20:55:25 Completed - Training job completedDocker entrypoint called with argument(s): train
# Running default environment configuration script
# /opt/amazon/lib/python2.7/site-packages/pandas/util/nosetester.py:13: DeprecationWarning: Importing from numpy.testing.nosetester is deprecated, import from numpy.testing instead.
#   from numpy.testing import nosetester
# [12/22/2020 20:52:30 INFO 140608586069824] Reading default configuration from /opt/amazon/lib/python2.7/site-packages/algorithm/resources/default-conf.json: {u'factors_lr': u'0.0001', u'linear_init_sigma': u'0.01', u'epochs': 1, u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'0.001', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.001', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'', u'bias_wd': u'0.01', u'use_linear': u'true', u'bias_lr': u'0.1', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'bias_init_sigma': u'0.01', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'0.00001', u'linear_wd': u'0.001', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [12/22/2020 20:52:30 INFO 140608586069824] Reading provided configuration from /opt/ml/input/config/hyperparameters.json: {u'epochs': u'200', u'factors_lr': u'0.22399378083337754', u'predictor_type': u'binary_classifier', u'_tuning_objective_metric': u'test:binary_classification_accuracy', u'bias_wd': u'0.036818989231449946', u'feature_dim': u'194219', u'factors_init_sigma': u'1.1397015502640903e-05', u'linear_init_sigma': u'0.0471727353721469', u'factors_wd': u'1.332628807461715', u'linear_lr': u'0.21538230404554873', u'linear_wd': u'9.939246970944074', u'bias_lr': u'0.015159919829520325', u'num_factors': u'64', u'bias_init_sigma': u'3.1506247110347184e-08', u'mini_batch_size': u'1000'}
# [12/22/2020 20:52:30 INFO 140608586069824] Final configuration: {u'factors_lr': u'0.22399378083337754', u'linear_init_sigma': u'0.0471727353721469', u'epochs': u'200', u'feature_dim': u'194219', u'num_factors': u'64', u'_wd': u'1.0', u'_num_kv_servers': u'auto', u'use_bias': u'true', u'factors_init_sigma': u'1.1397015502640903e-05', u'_log_level': u'info', u'bias_init_method': u'normal', u'linear_init_method': u'normal', u'linear_lr': u'0.21538230404554873', u'factors_init_method': u'normal', u'_tuning_objective_metric': u'test:binary_classification_accuracy', u'bias_wd': u'0.036818989231449946', u'use_linear': u'true', u'bias_lr': u'0.015159919829520325', u'mini_batch_size': u'1000', u'_use_full_symbolic': u'true', u'batch_metrics_publish_interval': u'500', u'predictor_type': u'binary_classifier', u'bias_init_sigma': u'3.1506247110347184e-08', u'_num_gpus': u'auto', u'_data_format': u'record', u'factors_wd': u'1.332628807461715', u'linear_wd': u'9.939246970944074', u'_kvstore': u'auto', u'_learning_rate': u'1.0', u'_optimizer': u'adam'}
# [12/22/2020 20:52:30 WARNING 140608586069824] Loggers have already been setup.
# Process 1 is a worker.
# [12/22/2020 20:52:30 INFO 140608586069824] Using default worker.
# [2020-12-22 20:52:30.715] [tensorio] [warning] TensorIO is already initialized; ignoring the initialization routine.
# [2020-12-22 20:52:30.724] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 0, "duration": 15, "num_examples": 1, "num_bytes": 64000}
# [12/22/2020 20:52:30 INFO 140608586069824] nvidia-smi took: 0.0251560211182 secs to identify 0 gpus
# [12/22/2020 20:52:30 INFO 140608586069824] Number of GPUs being used: 0
# [12/22/2020 20:52:30 INFO 140608586069824] [Sparse network] Building a sparse network.
# [12/22/2020 20:52:30 INFO 140608586069824] Create Store: local
# #metrics {"Metrics": {"initialize.time": {"count": 1, "max": 52.62398719787598, "sum": 52.62398719787598, "min": 52.62398719787598}}, "EndTime": 1608670350.773081, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670350.70771}
#
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Number of Batches Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Number of Records Since Last Reset": {"count": 1, "max": 0, "sum": 0.0, "min": 0}, "Total Batches Seen": {"count": 1, "max": 1, "sum": 1.0, "min": 1}, "Total Records Seen": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Max Records Seen Between Resets": {"count": 1, "max": 1000, "sum": 1000.0, "min": 1000}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1608670350.773356, "Dimensions": {"Host": "algo-1", "Meta": "init_train_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670350.773303}
#
# [20:52:30] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.203343.0/AL2012/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [20:52:30] /opt/brazil-pkg-cache/packages/AIAlgorithmsMXNet/AIAlgorithmsMXNet-1.1.x.203343.0/AL2012/generic-flavor/src/src/kvstore/./kvstore_local.h:280: Warning: non-default weights detected during kvstore pull. This call has been ignored. Please make sure to use row_sparse_pull with row_ids.
# [12/22/2020 20:52:31 INFO 140608586069824] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_accuracy <score>=0.508
# [12/22/2020 20:52:31 INFO 140608586069824] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_classification_cross_entropy <loss>=0.694232421875
# [12/22/2020 20:52:31 INFO 140608586069824] #quality_metric: host=algo-1, epoch=0, batch=0 train binary_f_1.000 <score>=0.669798657718
# [2020-12-22 20:52:32.473] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 2, "duration": 973, "num_examples": 68, "num_bytes": 4323840}
# [12/22/2020 20:52:32 INFO 140608586069824] #quality_metric: host=algo-1, epoch=0, train binary_classification_accuracy <score>=0.931264705882
# [12/22/2020 20:52:32 INFO 140608586069824] #quality_metric: host=algo-1, epoch=0, train binary_classification_cross_entropy <loss>=0.50376202976
# [12/22/2020 20:52:32 INFO 140608586069824] #quality_metric: host=algo-1, epoch=0, train binary_f_1.000 <score>=0.964386400695
# #metrics {"Metrics": {"epochs": {"count": 1, "max": 200, "sum": 200.0, "min": 200}, "update.time": {"count": 1, "max": 1700.8240222930908, "sum": 1700.8240222930908, "min": 1700.8240222930908}}, "EndTime": 1608670352.474476, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670350.773176}
#
# [12/22/2020 20:52:32 INFO 140608586069824] #progress_metric: host=algo-1, completed 0 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Batches Since Last Reset": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Records Since Last Reset": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Total Batches Seen": {"count": 1, "max": 69, "sum": 69.0, "min": 69}, "Total Records Seen": {"count": 1, "max": 68560, "sum": 68560.0, "min": 68560}, "Max Records Seen Between Resets": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Reset Count": {"count": 1, "max": 2, "sum": 2.0, "min": 2}}, "EndTime": 1608670352.474773, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 0}, "StartTime": 1608670350.773618}
#
# [12/22/2020 20:52:32 INFO 140608586069824] #throughput_metric: host=algo-1, train throughput=39711.345831 records/second
# [12/22/2020 20:52:32 INFO 140608586069824] #quality_metric: host=algo-1, epoch=1, batch=0 train binary_classification_accuracy <score>=0.986
# [12/22/2020 20:52
batch=0 train binary_f_1.000 <score>=0.992950654582
# [2020-12-22 20:55:03.350] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 392, "duration": 808, "num_examples": 68, "num_bytes": 4323840}
# [12/22/2020 20:55:03 INFO 140608586069824] #quality_metric: host=algo-1, epoch=195, train binary_classification_accuracy <score>=0.979808823529
# [12/22/2020 20:55:03 INFO 140608586069824] #quality_metric: host=algo-1, epoch=195, train binary_classification_cross_entropy <loss>=0.150637713376
# [12/22/2020 20:55:03 INFO 140608586069824] #quality_metric: host=algo-1, epoch=195, train binary_f_1.000 <score>=0.989801451418
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 810.6770515441895, "sum": 810.6770515441895, "min": 810.6770515441895}}, "EndTime": 1608670503.350951, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670502.539635}
#
# [12/22/2020 20:55:03 INFO 140608586069824] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Batches Since Last Reset": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Records Since Last Reset": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Total Batches Seen": {"count": 1, "max": 13329, "sum": 13329.0, "min": 13329}, "Total Records Seen": {"count": 1, "max": 13242760, "sum": 13242760.0, "min": 13242760}, "Max Records Seen Between Resets": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Reset Count": {"count": 1, "max": 197, "sum": 197.0, "min": 197}}, "EndTime": 1608670503.351323, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 195}, "StartTime": 1608670502.540242}
#
# [12/22/2020 20:55:03 INFO 140608586069824] #throughput_metric: host=algo-1, train throughput=83280.1172993 records/second
# [12/22/2020 20:55:03 INFO 140608586069824] #quality_metric: host=algo-1, epoch=196, batch=0 train binary_classification_accuracy <score>=0.986
# [12/22/2020 20:55:03 INFO 140608586069824] #quality_metric: host=algo-1, epoch=196, batch=0 train binary_classification_cross_entropy <loss>=0.134227813721
# [12/22/2020 20:55:03 INFO 140608586069824] #quality_metric: host=algo-1, epoch=196, batch=0 train binary_f_1.000 <score>=0.992950654582
# [2020-12-22 20:55:04.119] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 394, "duration": 766, "num_examples": 68, "num_bytes": 4323840}
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=196, train binary_classification_accuracy <score>=0.979808823529
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=196, train binary_classification_cross_entropy <loss>=0.150637964585
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=196, train binary_f_1.000 <score>=0.989801451418
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 768.7082290649414, "sum": 768.7082290649414, "min": 768.7082290649414}}, "EndTime": 1608670504.120473, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670503.351061}
#
# [12/22/2020 20:55:04 INFO 140608586069824] #progress_metric: host=algo-1, completed 98 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Batches Since Last Reset": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Records Since Last Reset": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Total Batches Seen": {"count": 1, "max": 13397, "sum": 13397.0, "min": 13397}, "Total Records Seen": {"count": 1, "max": 13310320, "sum": 13310320.0, "min": 13310320}, "Max Records Seen Between Resets": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Reset Count": {"count": 1, "max": 198, "sum": 198.0, "min": 198}}, "EndTime": 1608670504.120777, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 196}, "StartTime": 1608670503.351733}
#
# [12/22/2020 20:55:04 INFO 140608586069824] #throughput_metric: host=algo-1, train throughput=87830.9316736 records/second
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=197, batch=0 train binary_classification_accuracy <score>=0.986
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=197, batch=0 train binary_classification_cross_entropy <loss>=0.134241592407
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=197, batch=0 train binary_f_1.000 <score>=0.992950654582
# [2020-12-22 20:55:04.936] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 396, "duration": 814, "num_examples": 68, "num_bytes": 4323840}
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=197, train binary_classification_accuracy <score>=0.979808823529
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=197, train binary_classification_cross_entropy <loss>=0.150632876564
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=197, train binary_f_1.000 <score>=0.989801451418
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 816.0779476165771, "sum": 816.0779476165771, "min": 816.0779476165771}}, "EndTime": 1608670504.937211, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670504.120542}
#
# [12/22/2020 20:55:04 INFO 140608586069824] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Batches Since Last Reset": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Records Since Last Reset": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Total Batches Seen": {"count": 1, "max": 13465, "sum": 13465.0, "min": 13465}, "Total Records Seen": {"count": 1, "max": 13377880, "sum": 13377880.0, "min": 13377880}, "Max Records Seen Between Resets": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Reset Count": {"count": 1, "max": 199, "sum": 199.0, "min": 199}}, "EndTime": 1608670504.937551, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 197}, "StartTime": 1608670504.121102}
#
# [12/22/2020 20:55:04 INFO 140608586069824] #throughput_metric: host=algo-1, train throughput=82737.6481333 records/second
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=198, batch=0 train binary_classification_accuracy <score>=0.986
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=198, batch=0 train binary_classification_cross_entropy <loss>=0.134177276611
# [12/22/2020 20:55:04 INFO 140608586069824] #quality_metric: host=algo-1, epoch=198, batch=0 train binary_f_1.000 <score>=0.992950654582
# [2020-12-22 20:55:05.700] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 398, "duration": 761, "num_examples": 68, "num_bytes": 4323840}
# [12/22/2020 20:55:05 INFO 140608586069824] #quality_metric: host=algo-1, epoch=198, train binary_classification_accuracy <score>=0.979808823529
# [12/22/2020 20:55:05 INFO 140608586069824] #quality_metric: host=algo-1, epoch=198, train binary_classification_cross_entropy <loss>=0.150633352728
# [12/22/2020 20:55:05 INFO 140608586069824] #quality_metric: host=algo-1, epoch=198, train binary_f_1.000 <score>=0.989801451418
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 763.4599208831787, "sum": 763.4599208831787, "min": 763.4599208831787}}, "EndTime": 1608670505.701401, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670504.937278}
#
# [12/22/2020 20:55:05 INFO 140608586069824] #progress_metric: host=algo-1, completed 99 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Batches Since Last Reset": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Records Since Last Reset": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Total Batches Seen": {"count": 1, "max": 13533, "sum": 13533.0, "min": 13533}, "Total Records Seen": {"count": 1, "max": 13445440, "sum": 13445440.0, "min": 13445440}, "Max Records Seen Between Resets": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Reset Count": {"count": 1, "max": 200, "sum": 200.0, "min": 200}}, "EndTime": 1608670505.701705, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 198}, "StartTime": 1608670504.937894}
#
# [12/22/2020 20:55:05 INFO 140608586069824] #throughput_metric: host=algo-1, train throughput=88438.3511859 records/second
# [12/22/2020 20:55:05 INFO 140608586069824] #quality_metric: host=algo-1, epoch=199, batch=0 train binary_classification_accuracy <score>=0.986
# [12/22/2020 20:55:05 INFO 140608586069824] #quality_metric: host=algo-1, epoch=199, batch=0 train binary_classification_cross_entropy <loss>=0.134217407227
# [12/22/2020 20:55:05 INFO 140608586069824] #quality_metric: host=algo-1, epoch=199, batch=0 train binary_f_1.000 <score>=0.992950654582
# [2020-12-22 20:55:06.456] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/train", "epoch": 400, "duration": 752, "num_examples": 68, "num_bytes": 4323840}
# [12/22/2020 20:55:06 INFO 140608586069824] #quality_metric: host=algo-1, epoch=199, train binary_classification_accuracy <score>=0.979808823529
# [12/22/2020 20:55:06 INFO 140608586069824] #quality_metric: host=algo-1, epoch=199, train binary_classification_cross_entropy <loss>=0.150637797075
# [12/22/2020 20:55:06 INFO 140608586069824] #quality_metric: host=algo-1, epoch=199, train binary_f_1.000 <score>=0.989801451418
# [12/22/2020 20:55:06 INFO 140608586069824] #quality_metric: host=algo-1, train binary_classification_accuracy <score>=0.979808823529
# [12/22/2020 20:55:06 INFO 140608586069824] #quality_metric: host=algo-1, train binary_classification_cross_entropy <loss>=0.150637797075
# [12/22/2020 20:55:06 INFO 140608586069824] #quality_metric: host=algo-1, train binary_f_1.000 <score>=0.989801451418
# #metrics {"Metrics": {"update.time": {"count": 1, "max": 755.1960945129395, "sum": 755.1960945129395, "min": 755.1960945129395}}, "EndTime": 1608670506.457206, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670505.701467}
#
# [12/22/2020 20:55:06 INFO 140608586069824] #progress_metric: host=algo-1, completed 100 % of epochs
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Batches Since Last Reset": {"count": 1, "max": 68, "sum": 68.0, "min": 68}, "Number of Records Since Last Reset": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Total Batches Seen": {"count": 1, "max": 13601, "sum": 13601.0, "min": 13601}, "Total Records Seen": {"count": 1, "max": 13513000, "sum": 13513000.0, "min": 13513000}, "Max Records Seen Between Resets": {"count": 1, "max": 67560, "sum": 67560.0, "min": 67560}, "Reset Count": {"count": 1, "max": 201, "sum": 201.0, "min": 201}}, "EndTime": 1608670506.457468, "Dimensions": {"Host": "algo-1", "Meta": "training_data_iter", "Operation": "training", "Algorithm": "factorization-machines", "epoch": 199}, "StartTime": 1608670505.701964}
#
# [12/22/2020 20:55:06 INFO 140608586069824] #throughput_metric: host=algo-1, train throughput=89407.9894187 records/second
# [12/22/2020 20:55:06 WARNING 140608586069824] wait_for_all_workers will not sync workers since the kv store is not running distributed
# [12/22/2020 20:55:06 INFO 140608586069824] Pulling entire model from kvstore to finalize
# #metrics {"Metrics": {"finalize.time": {"count": 1, "max": 25.06089210510254, "sum": 25.06089210510254, "min": 25.06089210510254}}, "EndTime": 1608670506.482887, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670506.457288}
#
# [12/22/2020 20:55:06 INFO 140608586069824] Saved checkpoint to "/tmp/tmpAqSeYg/state-0001.params"
# [2020-12-22 20:55:06.816] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 0, "duration": 156101, "num_examples": 1, "num_bytes": 64000}
# [2020-12-22 20:55:09.537] [tensorio] [info] epoch_stats={"data_pipeline": "/opt/ml/input/data/test", "epoch": 1, "duration": 2719, "num_examples": 34, "num_bytes": 2129664}
# #metrics {"Metrics": {"Max Batches Seen Between Resets": {"count": 1, "max": 34, "sum": 34.0, "min": 34}, "Number of Batches Since Last Reset": {"count": 1, "max": 34, "sum": 34.0, "min": 34}, "Number of Records Since Last Reset": {"count": 1, "max": 33276, "sum": 33276.0, "min": 33276}, "Total Batches Seen": {"count": 1, "max": 34, "sum": 34.0, "min": 34}, "Total Records Seen": {"count": 1, "max": 33276, "sum": 33276.0, "min": 33276}, "Max Records Seen Between Resets": {"count": 1, "max": 33276, "sum": 33276.0, "min": 33276}, "Reset Count": {"count": 1, "max": 1, "sum": 1.0, "min": 1}}, "EndTime": 1608670509.537439, "Dimensions": {"Host": "algo-1", "Meta": "test_data_iter", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670506.816696}
#
# [12/22/2020 20:55:09 INFO 140608586069824] #test_score (algo-1) : ('binary_classification_accuracy', 0.9868674119485515)
# [12/22/2020 20:55:09 INFO 140608586069824] #test_score (algo-1) : ('binary_classification_cross_entropy', 0.13229773941342685)
# [12/22/2020 20:55:09 INFO 140608586069824] #test_score (algo-1) : ('binary_f_1.000', 0.9933903047719882)
# [12/22/2020 20:55:09 INFO 140608586069824] #quality_metric: host=algo-1, test binary_classification_accuracy <score>=0.986867411949
# [12/22/2020 20:55:09 INFO 140608586069824] #quality_metric: host=algo-1, test binary_classification_cross_entropy <loss>=0.132297739413
# [12/22/2020 20:55:09 INFO 140608586069824] #quality_metric: host=algo-1, test binary_f_1.000 <score>=0.993390304772
# #metrics {"Metrics": {"totaltime": {"count": 1, "max": 158888.1151676178, "sum": 158888.1151676178, "min": 158888.1151676178}, "setuptime": {"count": 1, "max": 51.30505561828613, "sum": 51.30505561828613, "min": 51.30505561828613}}, "EndTime": 1608670509.538475, "Dimensions": {"Host": "algo-1", "Operation": "training", "Algorithm": "factorization-machines"}, "StartTime": 1608670506.482972}
# Training seconds: 228
# Billable seconds: 228
# ---------------!

# %% [markdown]
# ## Helper function to serialize Inference requests

# %%
def fm_serializer(data):
    js = {"instances": []}
    for row in data:
        js["instances"].append({"features": row.tolist()})
    return json.dumps(js).encode()


fm_classifier_pred.serializer = fm_serializer
fm_classifier_pred.deserializer = json_deserializer

# %% [markdown]
# ## Making Predictions

# %%
fm_classifier_result = fm_classifier_pred.predict(X_test[1002:1009].toarray())

# %%
predictions = pd.DataFrame(fm_classifier_result)
# Out:
# {'predictions': [{'predicted_label': 1.0, 'score': 0.9017724394798279}, {'predicted_label': 1.0, 'score': 0.9028304219245911}, {'predicted_label': 1.0, 'score': 0.902442455291748}, {'predicted_label': 1.0, 'score': 0.9020636081695557}, {'predicted_label': 1.0, 'score': 0.9020634293556213}, {'predicted_label': 1.0, 'score': 0.9030724167823792}, {'predicted_label': 1.0, 'score': 0.901659369468689}]}

# %%
Actuals = pd.DataFrame(Y_test[1002:1009])
# Out:
# [1. 1. 1. 1. 1. 1. 1.]
